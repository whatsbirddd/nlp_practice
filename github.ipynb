# %%
from os.path import join
from google.colab import drive

ROOT='/content/drive'
drive.mount(ROOT)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pwd
# !ls /content/drive/MyDrive/자연어처리/'딥러닝을 이용한 자연어처리 입문' #경로 명 내에 띄어쓰기는 ''로 묶는다
# Out:
# /content
# 워드임베딩  github.ipynb  토큰화,정제,정규화.ipynb

# %%
PROJ = "/drive/MyDrive/자연어처리/'딥러닝을 이용한 자연어처리 입문'"
PROJ_PATH=join(ROOT,PROJ)

# %%
import os
import sys

sys.path.insert(0, PROJ_PATH)

# %%
# %cd /content/drive/MyDrive/자연어처리/'딥러닝을 이용한 자연어처리 입문'
# Out:
# /content/drive/MyDrive/자연어처리/딥러닝을 이용한 자연어처리 입문

# %%
# !pwd
# Out:
# /content/drive/MyDrive/자연어처리/딥러닝을 이용한 자연어처리 입문

# %%
# !git clone https://github.com/whatsbirddd/nlp_practice.git
# Out:
# Cloning into 'nlp_practice'...
# ...

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/My Drive/자연어처리/딥러닝을 이용한 자연어처리 입문/.git/

# %%
# !git config --global user.email "srpark2545@gmail.com"
# !git config --global user.name "whatsbird"
